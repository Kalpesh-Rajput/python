# %% [markdown]
# ### Day-1 (13-01-2026)
# ### problem 1 :
#
# The Challenge:
# Write a Python function that takes a string as input and returns a dictionary. The dictionary keys should be the characters in the string, and the values should be the number of times each character appears.
#
# Example:
#
# Input: "banana"
#
# Output: {'b': 1, 'a': 3, 'n': 2}

# %%
li = "banana"
dic = dict.fromkeys(li,0)
# print(dic.values())

for char in li:
    if char in dic:
        dic[char] += 1
print(dic)

# %% [markdown]
# ### Problem- 2
# The "FizzBuzz" List Filter
# The Challenge:
# Write a Python program that takes a list of numbers from 1 to 20. Create a new list based on these rules:
#
# If the number is divisible by 3, replace it with the string "Fizz".
#
# If the number is divisible by 5, replace it with the string "Buzz".
#
# If it is divisible by both 3 and 5, replace it with "FizzBuzz".
#
# Otherwise, just keep the number.
#
# Example:
#
# Input: [1, 2, 3, 4, 5, 15]
#
# Output: [1, 2, "Fizz", 4, "Buzz", "FizzBuzz"]

# %%
p = [1,2,3,10,15]
for n,i in enumerate(p):
    if i%3==0 and i%5==0:
        p[n] = "FizzBuzz"
    elif i%3 ==0: 
        p[n] = "Fizz"
    elif  i%5 ==0:
        p[n] = "Buzz"     
print(p)
# Out:
# [1, 2, 'Fizz', 'Buzz', 'FizzBuzz']

# %% [markdown]
# ### Problem 3:
#
# The List "Unique-ifier"
# Let's stick with the challenge I mentioned before, as it introduces a very powerful Python concept.
#
# The Challenge:
# You have a list with many duplicate items. You need to remove all duplicates so that every item appears only once.
#
# Example:
#
# Input: ["apple", "banana", "apple", "orange", "banana", "apple"]
#
# Output: ["apple", "banana", "orange"] (The order doesn't strictly matter for this challenge).

# %%
Input = ["apple", "banana", "apple", "orange", "banana", "apple"]
p = []
for i in Input:
    if i not in p:
        p.append(i)
print(p)

######## Way 2####

set(Input)
# Out:
# ['apple', 'banana', 'orange']
# {'apple', 'banana', 'orange'}

# %% [markdown]
# ### Problem 4:
#
# The Vowel Counter
# Input: "programming is fun"
#
# Expected Output: {'o': 1, 'a': 1, 'i': 1, 'u': 1} (or similar, depending on which vowels are present).
#
# Give it a go! I'll be here to check your code. After this, we'll pick up Day 5 tomorrow.
#
# What's your plan for the vowel check—will you use an if statement or a predefined list of vowels?

# %%
Input = "programming is fun"
vovel = "aeiou"
dic= dict.fromkeys(vovel,0)

for char in Input:
    lw = char.lower()
    if lw in vovel:
        dic[lw] +=1 
print(dic)
# Out:
# {'a': 1, 'e': 0, 'i': 2, 'o': 1, 'u': 1}

# %%
Input = "programming is fun"
vovel = "aeiou"
dic= {}

for char in Input:
    lw = char.lower()
    if lw in vovel:
        if lw in dic:
            dic[lw] +=1 
            
        else:
            dic[lw] = 1
print(dic)
# Out:
# {'o': 1, 'a': 1, 'i': 2, 'u': 1}

# %% [markdown]
# # Day - 2 (16-01-2026)
#
# Check Palindrom for number

# %%
class Solution:
    def isPalindrome(self, x: int) -> bool:
        if str(x) == str(x)[::-1]:
            return True
        else:
            return False

# %% [markdown]
# # Day - 2 (31-01-2026)
# Transpose Metrix
# matrix = [ [1, 2], [3, 4], [5, 6] ]
#
# OP = [[1, 3, 5], [2, 4, 6]]

# %% [markdown]
# # Day - 3 (01-04-2026)
# Convert this 3x2 matrix into a 2x3  matrix (turn rows into columns).
#
# **The Matrix Transpose**.
#
# ```python
# matrix = [
#     [1, 2],
#     [3, 4],
#     [5, 6]
# ]
# ```
#
# **Expected Output:** `[[1, 3, 5], [2, 4, 6]]`

# %%
matrix = [
    [1, 2],
    [3, 4],
    [5, 6]
]

transpose = []

for i in range(2):
    new_row = []
    # print(i)
    
    for row in matrix:
        # print(row)
        new_row.append(row[i])
        
    transpose.append(new_row)
    
print(transpose)



# Transpose Two matrix

a = [[6,4,2],
     [0,1,7]]
new = []
for i in range(3):
    new_row = []
    
    for j in a:
        # print(j)
        new_row.append(j[i])
    # print(j)
    new.append(new_row)
print(new)


#approach : 2
# b = [[0,0],
#       [0,0],
#       [0,0]]

# for i in range(len(a)):
#   for p in range(len(a[0])):
#     b[p][i] = a[i][p]

# for j in b:
#   print(j)
# Out:
# [[1, 3, 5], [2, 4, 6]]
# [0, 1, 7]
# [0, 1, 7]
# [0, 1, 7]
# [[6, 0], [4, 1], [2, 7]]
