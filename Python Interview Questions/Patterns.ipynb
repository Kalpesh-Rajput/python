# %%
for i in range(7):
    for j in range(i+1):
        print("*" , end="")
    print("")
    
for i in range(6):
    print("*"*(i))
# Out:
# *
# **
# ***
# ****
# *****

# %%
for i in range(6,0,-1):
    for j in range(i):
        print("*", end="")
    print("")
    


for i in range(6):
    for j in range(6-i):
        print("*", end="")
    print("")
    
for i in range(6,0,-1):
    print("*"*i)
# Out:
# ******
# *****
# ****
# ***
# **
# *

# %%
for i in range(6):
    for j in range(6-i):
        print(" " , end="")
    for c in range(i):
        print("*", end="")
    print("")
    
for i in range(6):
    print(" "*(6-i)+"*"*i)
# Out:
#
#      *
#     **
#    ***
#   ****
#  *****

# %%
for i in range(6):
    for j in range(6 -i ):
        print(" " , end="")
    for k in range(2*i-1):
        print("*" ,end="")
    print("")
    
for i in range(6):
    print(" "*(6-i)+"*"*(2*i-1))
# Out:
#
#      *
#     ***
#    *****
#   *******
#  *********

# %%
for i in range(6,0,-1):
    for j in range(6 -i ):
        print(" " , end="")
    for k in range(2*i-1):
        print("*" ,end="")
    print("")

for i in range(6,0,-1):
    print(" "*(6-i)+"*"*(2*i-1))
# Out:
# ***********
#  *********
#   *******
#    *****
#     ***
#      *

# %%
for i in range(6):
    print(" "*(6-i)+"*"*(2*i-1))
for i in range(6,0,-1):
    print(" "*(6-i)+"*"*(2*i-1))
# Out:
#
#      *
#     ***
#    *****
#   *******
#  *********
# ***********
#  *********
#   *******
#    *****
#     ***
#      *

# %%
start = [1 , 2 , 6 , 1 ,1]

for i in start:
    print(" "*i + "*" * i)
# Out:
#  *
#   **
#       ******
#  *
#  *
