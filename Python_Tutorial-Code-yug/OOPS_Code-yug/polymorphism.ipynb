# %% [markdown]
# # Polymorphism

# %% [markdown]
# What is Polymorphism ?
# * Polymorphism in python is an ability python object to take many form
# * if a variable, object, method performs different behaviours according to situation is called as Polymorphism
# * made from two greek words poly = mini , morph = form Something having numbers of forms
