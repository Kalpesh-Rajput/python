# %%
import requests

proxies = {
  "http": "http://10.10.1.10:3128",
  "https": "https://10.10.1.10:1080",
}

# Pass the proxies dictionary to the requests.get method
r = requests.get("https://api64.ipify.org?format=json")

# Print the JSON response which contains your IP address
print(r.json())
# Out:
# {'ip': '2409:40c1:2e:61f4:ed95:77c:c26:e845'}
