# %%
import requests
from bs4 import BeautifulSoup   


with open("Sample.html" , "r") as f:
    html_doc= f.read()

soup = BeautifulSoup(html_doc,"html.parser")
# print(soup.prettify())
# print(soup.title.name ,type(soup.title))
# print(soup.title.string)
# print(soup.find_all("div"))
# print(soup.find_all("div")[0])


# for links in soup.find_all("a"):
#     print(links.get("href"))

# print(soup.find(id = "Link3"))

# print(soup.find(class_ = "italic"))

# for con in soup.find(class_ = "container").children:
#     print(con)

# p = soup.find(class_ = "Kalpesh").text
# p

# i = 0
# for con_ in soup.find(class_ = "box").parents:
#     i += 1
#     print(con_)
#     if (i==2):
#         break

count_ = soup.find(class_ = "container")
count_.name = "span"
count_['class'] = "MyClass Class2"

print(count_)
# Out:
# <span class="MyClass Class2">
# <div class="box">i am a box </div>
# <div class="box">i am a Fox </div>
# <div class="box">i am a Crock </div>
# <div class="box">i am a rock </div>
# </span>
